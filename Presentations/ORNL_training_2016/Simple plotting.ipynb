# %% [markdown]
# # Simple plotting

# %% [markdown]
# For these examples, go first to `View->Preferences`, select `2D Plots`, then un-check `Normalize histogram to bin width`

# %% [markdown]
# ## 1D plots

# %% [markdown]
# One can right click on a workspace in the workspace toolbox and select `Plot Spectrum`
# * Load "MAR11060".
# * Right click the workspace in the workspace list.
# * Select "Plot Spectrum ...".
# * In the dialog that appears enter "1-3" in the spectra number box.
# * You should get a plot like this with three spectra corresponding to spectra 1-3 (which in this case these are the monitors on MARI):

# %%
from IPython.display import Image
Image(filename='images/MARI_monitors.png')

# %% [markdown]
# One can plot from the matrix view:
# * Display the matrix window for the data
# * Select rows corresponding to spectra 201-203 and 205:
#     * Click the index label of spectra 201, and then hold shift while selecting the last.
#     * While holding Ctrl, click on row 205
# * Right click on the spectra and select `Plot spectra (values only)`

# %%
Image(filename='images/PlotMatrixView.png')

# %% [markdown]
# **Adding a curve to an existing plot**
#
# There are two ways to add spectra to an already existing graph, either from the same workspace of from another.
#
# *Drag and Drop*
#
#    * Drag the Workspace from the Workspace List and drop it onto the graph you want to add the curve to.
#    * If the Workspace contains more than one spectra you will be asked which you wish to add to the plot.
#
# *From Another Plot*
#
#    * Create a plot containing the spectra or curve you want to import into your destination plot.
#    * In the destination plot double click the "1" in the top left.
#    * In the "Add/Remove Curves Dialog" that appears, select the data you want from the available data, and click "->" to add it to your plot.

# %% [markdown]
# ## 2D Plots

# %% [markdown]
# Visualizing a large number of spectra is easier using 2D plots
#
# ** Color Fill plots**
#
# * Load the MAR11060 dataset.
# * Right click the workspace in the workspace list and select `Colour Fill Plot`. This will create a fairly boring blue display of the data, because one spectrum contains much higher counts than any of the other spectra, and the color scale has adjusted accordingly.
# * To make the colour fill plot more sensitive to its smaller features, right-click on the plot and select `Colour Bar->Log Scale`.
# * Finally, right-clicking on the colour bar and selecting `Rescale to show all` will give a more meaningful result:

# %%
Image(filename='images/Mari2D.png')

# %% [markdown]
# Note that right clicking on the plot and selecting `Properties` will allow you to change color map, ad contour lines, and so on.
#
# **Spectrum Viewer**
#
# The Spectrum viewer is a useful way to investigate 2D image data. You can rapidly look through the spectrum and bin data for any point in the 2D map. To launch the Spectrum Viewer just right-click on the MAR11060 Workspace and select `Show Spectrum Viewer`:

# %%
Image(filename='images/MariSpectrumViewer.png')

# %% [markdown]
# **Slice viewer**
#
# While the Slice Viewer is mostly use to look at multi-dimensional workspaces, one can also use it to look at matrix workspace. Right click on the workspace, then select `Show Slice Viewer`

# %%
Image(filename='images/MariSliceViewer.png')

# %% [markdown]
# **Exercise:**
#
# Load the CNCS7860 dataset (including monitors). Try to repeat the steps above to produce some plots. Why can't you plot spectra from the data? (Hint: click on the arrow in the workspace toolbox and check information about the workspace)
